# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

x = np.arange(0, 10, 0.1)
y = -0.5 * np.cos(x) + 1

plt.figure(figsize=(10,2))

plt.xlabel("time")
plt.ylabel("focus")

_ = plt.plot(x, y)
